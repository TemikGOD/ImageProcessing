# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
from pathlib import Path
from tqdm import tqdm

plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# ---
# ## 1. Подготовка датасета для YOLO

# %%
IMAGES_DIR = Path('MSFD/1/face_crop')
MASKS_DIR = Path('MSFD/1/face_crop_segmentation')
OUTPUT_DIR = Path('dataset_yolo')

images = sorted(list(IMAGES_DIR.glob('*.jpg')))
masks = sorted(list(MASKS_DIR.glob('*.jpg')))

print(f'Images: {len(images)}')
print(f'Masks: {len(masks)}')

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
img = cv2.imread(str(images[0]))
mask = cv2.imread(str(masks[0]), cv2.IMREAD_GRAYSCALE)

axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
axes[0].set_title('Image', fontweight='bold')
axes[0].axis('off')

axes[1].imshow(mask, cmap='gray')
axes[1].set_title('Mask', fontweight='bold')
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Images: 9383
# Masks: 9383

# %%
def mask_to_yolo_polygon(mask_path, class_id=0):
    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        return None
    
    h, w = mask.shape
    
    _, binary = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
    
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if not contours:
        return None
    
    largest = max(contours, key=cv2.contourArea)
    
    if len(largest) < 3:
        return None
    
    epsilon = 0.005 * cv2.arcLength(largest, True)
    approx = cv2.approxPolyDP(largest, epsilon, True)
    
    if len(approx) < 3:
        approx = largest
    
    points = approx.reshape(-1, 2)
    normalized = []
    for x, y in points:
        normalized.extend([x / w, y / h])
    
    coords = ' '.join([f'{v:.6f}' for v in normalized])
    return f'{class_id} {coords}'

test_label = mask_to_yolo_polygon(masks[0])
print('Example YOLO label:')
print(test_label[:100] + '...')
# Out:
# Example YOLO label:
# 0 0.000000 0.195062 0.000000 0.609877 0.324742 0.997531 0.608247 0.997531 0.863402 0.743210 0.889175...

# %%
def create_yolo_dataset(images_dir, masks_dir, output_dir, train_ratio=0.8):
    output = Path(output_dir)
    
    if output.exists():
        shutil.rmtree(output)
    
    for split in ['train', 'val']:
        (output / split / 'images').mkdir(parents=True)
        (output / split / 'labels').mkdir(parents=True)
    
    images = sorted(list(Path(images_dir).glob('*.jpg')))
    
    np.random.seed(42)
    indices = np.random.permutation(len(images))
    
    train_size = int(len(images) * train_ratio)
    train_idx = indices[:train_size]
    val_idx = indices[train_size:]
    
    stats = {'train': 0, 'val': 0, 'skipped': 0}
    
    for split, idx_list in [('train', train_idx), ('val', val_idx)]:
        for idx in tqdm(idx_list, desc=f'{split}'):
            img_path = images[idx]
            mask_path = Path(masks_dir) / img_path.name
            
            if not mask_path.exists():
                stats['skipped'] += 1
                continue
            
            label = mask_to_yolo_polygon(mask_path)
            if label is None:
                stats['skipped'] += 1
                continue
            
            shutil.copy(img_path, output / split / 'images' / img_path.name)
            
            label_name = img_path.stem + '.txt'
            with open(output / split / 'labels' / label_name, 'w') as f:
                f.write(label)
            
            stats[split] += 1
    
    return stats

stats = create_yolo_dataset(IMAGES_DIR, MASKS_DIR, OUTPUT_DIR)
print(f'\nDone!')
print(f"Train: {stats['train']}")
print(f"Val: {stats['val']}")
print(f"Skipped: {stats['skipped']}")
# Out:
# train: 100%|██████████| 7506/7506 [00:21<00:00, 341.33it/s]
# val: 100%|██████████| 1877/1877 [00:03<00:00, 475.20it/s]
# Done!
# Train: 7502
# Val: 1877
# Skipped: 4

# %%
dataset_yaml = f"""path: {OUTPUT_DIR.absolute()}
train: train/images
val: val/images

names:
  0: mask
"""

with open(OUTPUT_DIR / 'dataset.yaml', 'w') as f:
    f.write(dataset_yaml.strip())

print('dataset.yaml created:')
print(dataset_yaml)
# Out:
# dataset.yaml created:
# path: e:\ImageProcessing\python\Lab_9(yolo)\dataset_yolo
# train: train/images
# val: val/images
#
# names:
#   0: mask

# %% [markdown]
# ---
# ## 2. Обучение YOLO11-seg

# %%
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n-seg.pt to 'yolo11n-seg.pt': 100% ━━━━━━━━━━━━ 5.9MB 10.3MB/s 0.6s.5s<0.1s8s3s

# %%
results = model.train(
    data=str(OUTPUT_DIR / 'dataset.yaml'),
    epochs=30,           # Количество эпох
    imgsz=640,           # Размер изображения
    batch=8,             # Размер батча (уменьшить если мало памяти)
    patience=10,         # Early stopping
    device=0,            # GPU (или 'cpu' если нет GPU)
    workers=2,
    project='runs',
    name='mask_seg'
)
# Out:
# Ultralytics 8.4.14  Python-3.11.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_yolo\dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=mask_seg, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=E:\ImageProcessing\python\Lab_9(yolo)\runs\segment\runs\mask_seg, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\denis\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 2.7MB/s 0.3s 0.2s<0.2ss
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    683635  ultralytics.nn.modules.head.Segment          [1, 32, 64, 16, None, [64, 128, 256]]
# YOLO11n-seg summary: 204 layers, 2,842,803 parameters, 2,842,787 gradients, 9.7 GFLOPs
#
# Transferred 510/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 8.5MB/s 0.6s0.6s<0.0s.6ss
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 153.0227.5 MB/s, size: 22.5 KB)
# train: Scanning E:\ImageProcessing\python\Lab_9(yolo)\dataset_yolo\train\labels... 7502 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7502/7502 460.9it/s 16.3s<0.1s
# train: New cache created: E:\ImageProcessing\python\Lab_9(yolo)\dataset_yolo\train\labels.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 253.1234.6 MB/s, size: 46.0 KB)
# val: Scanning E:\ImageProcessing\python\Lab_9(yolo)\dataset_yolo\val\labels... 1877 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1877/1877 403.4it/s 4.7s0.1s
# val: New cache created: E:\ImageProcessing\python\Lab_9(yolo)\dataset_yolo\val\labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 90 weight(decay=0.0), 101 weight(decay=0.0005), 100 bias(decay=0.0)
# Plotting labels to E:\ImageProcessing\python\Lab_9(yolo)\runs\segment\runs\mask_seg\labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to E:\ImageProcessing\python\Lab_9(yolo)\runs\segment\runs\mask_seg
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        1/30      1.46G     0.7079      1.406     0.9774      1.188          0         14        640: 100% ━━━━━━━━━━━━ 938/938 6.6it/s 2:21<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118 4.8it/s 24.8s0.2s
#                    all       1877       1877      0.955      0.959       0.98      0.784      0.955       0.95      0.973      0.767
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        2/30      1.91G     0.7349      1.293     0.5862      1.196          0         19        640: 100% ━━━━━━━━━━━━ 938/938 6.8it/s 2:18<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118 4.9it/s 24.2s0.2s
#                    all       1877       1877      0.985      0.983      0.993      0.825       0.98      0.978      0.984      0.844
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#        3/30      1.91G     0.7235      1.267     0.5315      1.184          0         18        640: 100% ━━━━━━━━━━━━ 938/938 6.4it/s 2:26<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       28/30      1.92G     0.3906     0.7024     0.2137      1.042          0          6        640: 100% ━━━━━━━━━━━━ 938/938 6.7it/s 2:20<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118 6.0it/s 19.8s0.2s
#                    all       1877       1877      0.994      0.992      0.995      0.932      0.989      0.987      0.994      0.921
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       29/30      1.92G     0.3871      0.693     0.2116      1.041          0          6        640: 100% ━━━━━━━━━━━━ 938/938 1.3s/it 20:48<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118 6.1it/s 19.3s0.2s
#                    all       1877       1877      0.996      0.991      0.995      0.927      0.994      0.988      0.995      0.918
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       30/30      1.92G      0.378     0.6781     0.2004      1.032          0          6        640: 100% ━━━━━━━━━━━━ 938/938 7.9it/s 1:59<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118 6.2it/s 19.2s0.2s
#                    all       1877       1877      0.995      0.993      0.995      0.931      0.994      0.987      0.995      0.921
#
# 30 epochs completed in 1.683 hours.
# Optimizer stripped from E:\ImageProcessing\python\Lab_9(yolo)\runs\segment\runs\mask_seg\weights\last.pt, 6.0MB
# Optimizer stripped from E:\ImageProcessing\python\Lab_9(yolo)\runs\segment\runs\mask_seg\weights\best.pt, 6.0MB
#
# Validating E:\ImageProcessing\python\Lab_9(yolo)\runs\segment\runs\mask_seg\weights\best.pt...
# Ultralytics 8.4.14  Python-3.11.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLO11n-seg summary (fused): 114 layers, 2,834,763 parameters, 0 gradients, 9.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118 6.3it/s 18.8s0.1s
#                    all       1877       1877      0.994      0.992      0.995      0.932      0.989      0.987      0.994      0.921
# Speed: 0.3ms preprocess, 2.1ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to E:\ImageProcessing\python\Lab_9(yolo)\runs\segment\runs\mask_seg

# %% [markdown]
# ---
# ## 3. Тестирование модели

# %%
best_model = YOLO('runs/segment/runs/mask_seg/weights/best.pt')

# %%
val_images = list((OUTPUT_DIR / 'val' / 'images').glob('*.jpg'))[:6]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for idx, img_path in enumerate(val_images):
    results = best_model(str(img_path), verbose=False)
    result_img = results[0].plot()
    axes[idx].imshow(cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB))
    axes[idx].set_title(img_path.name, fontweight='bold')
    axes[idx].axis('off')

plt.suptitle('Results of Mask Segmentation', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
def predict_mask(image_path, conf=0.5):
    results = best_model(str(image_path), conf=conf, verbose=False)
    
    img = cv2.imread(str(image_path))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    result_img = cv2.cvtColor(results[0].plot(), cv2.COLOR_BGR2RGB)
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    axes[0].imshow(img_rgb)
    axes[0].set_title('Original', fontweight='bold')
    axes[0].axis('off')
    
    axes[1].imshow(result_img)
    axes[1].set_title('Segmentation', fontweight='bold')
    axes[1].axis('off')
    
    plt.tight_layout()
    plt.show()
    
    n_masks = len(results[0].boxes) if results[0].boxes is not None else 0
    print(f'Found masks: {n_masks}')

predict_mask(val_images[0])
# Out:
# Found masks: 1

# %%
other_images = list(Path('MSFD/2/img').glob('*.jpg'))[:3]

for img_path in other_images:
    print(f'\n--- {img_path.name} ---')
    predict_mask(img_path, conf=0.3)
# Out:
# --- 114827560_612637226347903_2763860821287827135_n.jpg ---
# Found masks: 1
#
# --- 1234carlton_130217032_1269039916807375_8534704696144444690_n.jpg ---
# Found masks: 2
#
# --- 129421898_393248228586637_4979851665036615942_n.jpg ---
# Found masks: 1
